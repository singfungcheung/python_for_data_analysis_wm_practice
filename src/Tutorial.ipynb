# %% [markdown]
# Chapter 2: Python Basics

# %%
print("Note book!")
# Out:
# Note book!

# %%
def add_numbers(a, b):
    """
    Add two numbers and return them.
    """
    return a + b

# %%
a = add_numbers(2,3)

# %%
isinstance(a, int)
# Out:
# True

# %%
isinstance(a, (int, float))
# Out:
# True

# %%
b = "Sing Fung"

# %%
b.capitalize()
# Out:
# 'Sing fung'

# %%
b.upper()
# Out:
# 'SING FUNG'

# %%
b.lower()
# Out:
# 'sing fung'

# %%
b.startswith('S')
# Out:
# True

# %%
iter([1,2,3])

# %% [markdown]
# Atrributes and methods

# %% [markdown]
# ![image.png](attachment:d95e517d-1e52-4be6-90e2-b9a6fd5b1e33.png)

# %%
# A common use of is and is not is to check if a variable is None, since there is only one instance of None.
a = None
a is None
# Out:
# True

# %%
3/2
# Out:
# 1.5

# %%
amount = 10
rate = 88.46
currency = "Pesos"
result = f"{amount} {currency} is worth US${amount / rate}"
result
# Out:
# '10 Pesos is worth US$0.11304544426859599'

# %%
# Make the decimal look neater.
result = f"{amount} {currency} is worth US${amount / rate:.2f}"
result
# Out:
# '10 Pesos is worth US$0.11'

# %%
# Dates and times
from datetime import datetime, date, time
dt = datetime(2024, 4, 10, 10, 38, 37)
dt.day
dt.minute
dt.second

dt.date()
dt.time()

# strftime method formats a dateimte as a string:
dt.strftime("%Y-%m-%d %H:%M")
# Out:
# '2024-04-10 10:38'

# %%
# Strings cna be converted (parsed) into datetime objects with the strptime function.
datetime.strptime("20240410", "%Y%m%d")
# Out:
# datetime.datetime(2024, 4, 10, 0, 0)

# %% [markdown]
# Chapter 3: Built-In Data Structures, Functions, and Files

# %%
# Tuples
tup = 4, 5, (6, 7)
a, b, c = tup

# %%
values = 1, 2, 3, 4, 5
a, b, *rest = values
c, d, *_ = values # *_ is convention for unwanted values
print(rest, _)
# Out:
# [3, 4, 5] [3, 4, 5]

# %% [markdown]
# # Extend is less expensive than concatenating lists.
# my_list = []
# my_list.extend([5, 6])
# my_list
# my_list = []
# my_list + [5, 6]

# %% [markdown]
# Dictionary

# %%
empty_dict = {}
d1 = {"a": "some value", "b": [1, 2, 3, 4]}
d1[7] = "an integer"
d1
# Out:
# {'a': 'some value', 'b': [1, 2, 3, 4], 7: 'an integer'}

# %%
d1["b"]
# Out:
# [1, 2, 3, 4]

# %%
# Merge one dictionary with another using the update method.
d1.update({"b": "foo", "c":12})
d1
# Out:
# {'a': 'some value', 7: 'an integer', 'b': 'foo', 'c': 12}

# %% [markdown]
# ![image.png](attachment:10b9a6e5-fa6f-4a0d-b2f4-674968f8392d.png)

# %%
{1,2,3,3}
# Out:
# {1, 2, 3}

# %%
def my_func(x, y, z = 1.5):
    if z > 1:
        return z * (x + y)
    else:
        return z / (x + y)
my_func(5, 6, 0.7)
my_func(3.14, 7, 3.5)
# Out:
# 35.49

# %%
# Maps. It applies a function to a sequence of some kind.
# for x in map(remove_punctuation, states): print(x)

# %%
# Anonymous (Lambda) Functions.
"""
Single statement and the result of which is the return value. Use "lambda" keyword.
"""
def short_function(x):
    return x * 2
equiv_anon = lambda x: x * 2
equiv_anon(2)

def apply_to_list(some_list, f):
    return [f(x) for x in some_list]

ints = [4, 0, 1, 5, 6]
apply_to_list(ints, lambda x: x * 2)
# Out:
# [8, 0, 2, 10, 12]

# %%
# Another example is sorting a collection of strings by the number of distinct letters in each string.
strings = ["foo", "card", "bar", "aaaa", "abab"]
strings.sort(key = lambda x: len(set(x)))
strings
# Out:
# ['aaaa', 'foo', 'abab', 'bar', 'card']
